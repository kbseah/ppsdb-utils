# %%
import pandas as pd
import json
from common import wbi_config, login, sparql_prefixes
from wikibaseintegrator import WikibaseIntegrator, datatypes, wbi_helpers
from wikibaseintegrator.models import References, Reference, Qualifiers

# %%
import requests

# %% [markdown]
# For each ncbi taxon ID, retrieve nucleotide accessions for that taxon, and filter for 16S rRNA sequences (keyword search for "16S", "SSU", "small subunit" in title).
#
# If there is only one SSU sequence available in the NCBI database for this taxon ID, then it must be the representative SSU rRNA sequence.

# %%
ppsdb_query = """
SELECT DISTINCT ?item ?ncbi WHERE {
  # ?item ppt:P11 ?ncbi.
  FILTER NOT EXISTS { ?item ppt:P34 ?ssu. }
}
"""

# %%
elink = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi"

esummary = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi"

# %%
ppsdb_recs = wbi_helpers.execute_sparql_query(query=ppsdb_query, prefix=sparql_prefixes)

# %%
qid2repseq = {}

# %%
for rec in ppsdb_recs['results']['bindings']:
    qid = rec['item']['value'].split("/")[-1]
    taxid = rec['ncbi']['value']
    print(qid, taxid)
    nuccore_query = {
        "dbfrom" : "taxonomy",
        "db" : "nucleotide",
        "id" : taxid,
        "idtype" : "acc",
        "retmode" : "json",
    }
    try:
        get_out = requests.get(elink, params=nuccore_query)
    except:
        print("elink query returned exception, skipping")
        continue
    if not get_out.ok:
        print("elink query not ok")
        continue
    try:
        ids = [i['links'] for i in json.loads(get_out.text)['linksets'][0]['linksetdbs'] if i['dbto'] == 'nuccore' and i['linkname'] == 'taxonomy_nuccore'][0]
    except:
        print(f"no links for {taxid}, skipping")
        continue
    print(f"nuccore sequences found: {str(len(ids))}")
    if len(ids) > 200:
        print("over 200 sequences retrieved, skipping")
        continue
    summary_query = {
        "db" : "nucleotide",
        "id" : ",".join(ids),
        "retmode" : "json"
    }
    try:
        summary_out = requests.get(esummary, params=summary_query)
    except:
        print("esummary query returned exception, skipping")
        continue
    if not summary_out.ok:
        print("esummary query not ok")
        continue
    uids = json.loads(summary_out.text)['result']['uids']
    ssu_accs = []
    for i in uids:
        rec = json.loads(summary_out.text)['result'][i]
        tests = ['16S' in rec['title'], 'SSU' in rec['title'], '18S' in rec['title'], 'small subunit' in rec['title'].lower(), 'small-subunit' in rec['title'].lower()]
        if any(tests):
            ssu_accs.append((rec['title'], rec['accessionversion']))
    if len(ssu_accs) == 1:
        print(ssu_accs)
        qid2repseq[qid] = ssu_accs[0]
# Out:
# Q7 1905158
# nuccore sequences found: 9
# Q8 2126337
# nuccore sequences found: 3641
# over 200 sequences retrieved, skipping
# Q16 219837
# nuccore sequences found: 1
# [('Geleia fossata small subunit ribosomal RNA gene, partial sequence', 'AY187925.1')]
# Q23 1981150
# nuccore sequences found: 541
# over 200 sequences retrieved, skipping
# Q24 1981151
# nuccore sequences found: 222
# over 200 sequences retrieved, skipping
# Q30 2126338
# nuccore sequences found: 707
# over 200 sequences retrieved, skipping
# Q31 1905156
# nuccore sequences found: 22
# Q32 2126562
# nuccore sequences found: 602
# over 200 sequences retrieved, skipping
# Q33 2126340
# nuccore sequences found: 3099
# over 200 sequences retrieved, skipping
# Q34 2126342
# nuccore sequences found: 1166
# over 200 sequences retrieved, skipping
# Q35 2126335
# nuccore sequences found: 2905
# over 200 sequences retrieved, skipping
# Q36 2138164
# nuccore sequences found: 639
# over 200 sequences retrieved, skipping
# Q37 2126332
# nuccore sequences found: 1816
# over 200 sequences retrieved, skipping
# Q38 2126339
# nuccore sequences found: 642
# over 200 sequences retrieved, skipping
# Q39 2126343
# nuccore sequences found: 2302
# over 200 sequences retrieved, skipping
# Q40 2126344
# nuccore sequences found: 1130
# over 200 sequences retrieved, skipping
# Q41 2126341
# nuccore sequences found: 3946
# over 200 sequences retrieved, skipping
# Q42 1905168
# nuccore sequences found: 4
# Q43 1905174
# nuccore sequences found: 2
# [('Kentrophoros sp. UNK partial 18S rRNA gene, isolate BY8', 'LT621912.1')]
# Q44 1905173
# nuccore sequences found: 3
# Q45 1905175
# nuccore sequences found: 28
# Q46 1905171
# nuccore sequences found: 46
# Q47 1905170
# nuccore sequences found: 29
# Q48 1905160
# nuccore sequences found: 7
# Q49 1905172
# nuccore sequences found: 3
# Q50 1905169
# nuccore sequences found: 4
# Q52 1934002
# nuccore sequences found: 8
# Q55 1934002
# nuccore sequences found: 8
# Q61 1175499
# nuccore sequences found: 2
# [('Chlorella sp. K10 gene for 18S rRNA, partial sequence', 'AB713411.1')]
# Q62 2784338
# nuccore sequences found: 2
# [('Candidatus Thiodictyon intracellulare clone MG01 16S ribosomal RNA gene, partial sequence', 'MW203126.1')]
# Q63 2528046
# nuccore sequences found: 2
# [('Pseudoblepharisma tenue isolate FL1 small subunit ribosomal RNA gene, partial sequence', 'MK543441.1')]
# Q81 1653305
# nuccore sequences found: 3
# [('Lenisia limosa strain LL-12 18S ribosomal RNA gene, partial sequence', 'KT023596.1')]
# Q82 1665555
# nuccore sequences found: 231
# over 200 sequences retrieved, skipping
# Q88 373042
# nuccore sequences found: 34
# Q89 713887
# nuccore sequences found: 106
# Q90 1315715
# nuccore sequences found: 2
# Q92 2510583
# nuccore sequences found: 1
# [('Pompholyxophrys punicea isolate LG129 small subunit ribosomal RNA gene, partial sequence', 'MK547175.1')]
# Q98 946362
# nuccore sequences found: 12108
# over 200 sequences retrieved, skipping
# Q99 388413
# nuccore sequences found: 9
# Q102 81531
# nuccore sequences found: 14
# Q103 517774
# nuccore sequences found: 20
# Q104 1885587
# nuccore sequences found: 13
# Q105 270368
# nuccore sequences found: 702
# over 200 sequences retrieved, skipping
# Q106 244253
# nuccore sequences found: 13
# Q107 244252
# nuccore sequences found: 1
# [('Rickettsia endosymbiont of Nuclearia pattersoni 16S ribosomal RNA gene, partial sequence', 'AY364636.1')]
# Q108 154968
# nuccore sequences found: 59
# Q110 1921806
# nuccore sequences found: 155
# Q111 1885581
# nuccore sequences found: 13
# Q112 1885583
# nuccore sequences found: 12
# Q114 1885585
# nuccore sequences found: 20
# Q118 85379
# nuccore sequences found: 1
# [('Roseobacter sp. (Prionitis filiformis symbiont) 16S ribosomal RNA gene, partial sequence', 'AF107209.1')]
# Q119 128579
# nuccore sequences found: 26
# Q120 85380
# nuccore sequences found: 1
# [('Roseobacter sp. (Prionitis decipiens symbiont) 16S ribosomal RNA gene, partial sequence', 'AF107210.1')]
# Q121 2293935
# nuccore sequences found: 21
# Q122 43074
# nuccore sequences found: 1
# [('Prionitis lanceolata gall symbiont 16S ribosomal RNA gene, complete sequence', 'U37762.1')]
# Q123 31457
# nuccore sequences found: 24
# Q124 63410
# nuccore sequences found: 497
# over 200 sequences retrieved, skipping
# Q125 111616
# nuccore sequences found: 678
# over 200 sequences retrieved, skipping
# Q126 314281
# nuccore sequences found: 200
# Q96 232288
# no links for 232288, skipping
# Q128 55601
# elink query not ok
# Q130 173728
# nuccore sequences found: 2
# [('Cytophaga sp. MBIC04671 gene for 16S ribosomal RNA, partial sequence', 'AB073554.2')]
# Q131 153904
# nuccore sequences found: 15
# Q132 1445552
# nuccore sequences found: 45
# [('Candidatus Phycosocius bacilliformis gene for 16S ribosomal RNA, partial sequence', 'AB900796.1')]
# Q133 38881
# nuccore sequences found: 1900
# over 200 sequences retrieved, skipping
# Q101 1194294
# nuccore sequences found: 9
# Q136 47906
# nuccore sequences found: 92
# [('Chlamydomonas nivalis 18S small subunit nuclear ribosomal RNA gene, partial sequence', 'U57696.1')]
# Q137 381
# nuccore sequences found: 3229
# over 200 sequences retrieved, skipping
# Q138 1727150
# nuccore sequences found: 1
# [('Lobomonas rostrata gene for 18S rRNA, partial sequence, strain: SAG 45-1', 'LC086369.1')]
# Q139 3067
# nuccore sequences found: 225
# over 200 sequences retrieved, skipping
# Q140 47287
# nuccore sequences found: 68
# Q141 988779
# nuccore sequences found: 250
# over 200 sequences retrieved, skipping
# Q142 47788
# nuccore sequences found: 50
# Q143 69401
# elink query not ok
# Q145 3046
# nuccore sequences found: 13038
# over 200 sequences retrieved, skipping
# Q146 2728
# nuccore sequences found: 10
# [('Amoeba proteus symbiotic bacterium 16S ribosomal RNA gene, complete sequence', 'AY598719.2')]
# Q147 5775
# nuccore sequences found: 26
# Q148 34073
# nuccore sequences found: 6095
# over 200 sequences retrieved, skipping
# Q149 704142
# nuccore sequences found: 8
# Q150 704159
# nuccore sequences found: 2
# Q151 1415177
# nuccore sequences found: 1
# [('Hartmannella sp. FS5 18S ribosomal RNA gene, partial sequence', 'KF697197.1')]
# Q152 1509244
# nuccore sequences found: 4
# [('Candidatus Nucleicultrix amoebiphila 16S ribosomal RNA gene, partial sequence', 'KF697195.1')]
# Q153 1763547
# nuccore sequences found: 5
# Q154 5778
# nuccore sequences found: 100
# Q155 112235
# nuccore sequences found: 18
# Q156 670882
# nuccore sequences found: 2
# Q163 1627872
# nuccore sequences found: 1
# [('Endosymbiont of Vannella sp. A1 gene for 16S ribosomal RNA, partial sequence', 'LC025959.1')]
# Q164 1628021
# nuccore sequences found: 1
# [('Vannella sp. A1 gene for 18S ribosomal RNA, partial sequence', 'LC025974.1')]
# Q166 1485075
# nuccore sequences found: 1
# [('Endostelium amerosporum 18S ribosomal RNA gene, partial sequence', 'KF705035.1')]
# Q167 668362
# nuccore sequences found: 1
# [('Endostelium zonatum strain LHI05M6a-1 culture-collection ATCC:PRA-191 clone 1 18S ribosomal RNA gene, partial sequence', 'FJ766469.1')]
# Q169 1078849
# nuccore sequences found: 7
# [('Gocevia fonbrunei strain ATCC 50196 small subunit ribosomal RNA gene, partial sequence', 'JF694281.1')]
# Q170 112244
# nuccore sequences found: 2
# [('Candidatus Procabacter acanthamoebae 16S ribosomal RNA gene, partial sequence', 'AF177427.1')]
# Q171 167753
# nuccore sequences found: 1
# [('Acanthamoeba sp. UWC12 18S ribosomal RNA gene, partial sequence', 'AF352390.1')]
# Q172 167755
# nuccore sequences found: 1
# [('Acanthamoeba sp. UWE2 18S ribosomal RNA gene, partial sequence', 'AF352388.1')]
# Q173 167754
# nuccore sequences found: 1
# [('Acanthamoeba sp. UWC6 18S ribosomal RNA gene, partial sequence', 'AF352387.1')]
# Q174 167751
# nuccore sequences found: 1
# [('Acanthamoeba sp. TUMSJ-226 18S ribosomal RNA gene, partial sequence', 'AF352389.1')]
# Q175 167752
# nuccore sequences found: 1
# [('Acanthamoeba sp. TUMSJ-341 18S ribosomal RNA gene, partial sequence', 'AF352391.1')]
# Q176 332198
# nuccore sequences found: 1
# [('Acanthamoeba sp. UWC9 18S ribosomal RNA gene, partial sequence', 'AF132134.1')]
# Q177 91604
# nuccore sequences found: 6
# [('Endosymbiont of Acanthamoeba sp. UWC9 16S ribosomal RNA gene, partial sequence', 'AF132137.1')]
# Q178 244582
# nuccore sequences found: 103
# Q179 332199
# nuccore sequences found: 1
# [('Acanthamoeba sp. UWET39 18S ribosomal RNA gene, partial sequence', 'AF132136.1')]
# Q180 5757
# nuccore sequences found: 142
# Q181 244581
# nuccore sequences found: 7
# Q183 172893
# nuccore sequences found: 1
# [('Acanthamoeba sp. TUMSJ-321 18S ribosomal RNA gene, complete sequence', 'AF366580.1')]
# Q185 281136
# nuccore sequences found: 1
# [('Endosymbiont of Acanthamoeba sp. RM-69 16S ribosomal RNA gene, partial sequence', 'AF366583.1')]
# Q189 84647
# nuccore sequences found: 626
# over 200 sequences retrieved, skipping
# Q191 362787
# nuccore sequences found: 418
# over 200 sequences retrieved, skipping
# Q193 415227
# nuccore sequences found: 1
# [('Candidatus Procabacter sp. OEW1 partial 16S rRNA gene', 'AM412761.1')]
# Q194 83552
# nuccore sequences found: 555
# over 200 sequences retrieved, skipping
# Q195 415243
# nuccore sequences found: 1
# Q197 295108
# nuccore sequences found: 8
# [('Candidatus Berkiella aquae isolate HT99 16S ribosomal RNA gene, partial sequence', 'AY741401.1')]
# Q198 437022
# nuccore sequences found: 7
# [('Candidatus Berkiella cookevillensis isolate CC99 16S ribosomal RNA gene, partial sequence', 'EF492067.1')]
# Q203 1857768
# nuccore sequences found: 1
# [('Methanosaeta sp. ARCH clone ARCH 16S ribosomal RNA gene, partial sequence', 'KX156800.1')]
# Q204 1857770
# nuccore sequences found: 1
# [('Rhodococcus sp. 17PEL clone 17PEL 16S ribosomal RNA gene, partial sequence', 'KX156801.1')]
# Q205 1857767
# nuccore sequences found: 1
# [('Syntrophorhabdus sp. 22PEL clone 22PEL 16S ribosomal RNA gene, partial sequence', 'KX156802.1')]
# Q206 168132
# nuccore sequences found: 4
# Q210 435424
# nuccore sequences found: 6
# Q211 1708752
# nuccore sequences found: 1
# [('Burkholderia sp. NC21 16S ribosomal RNA gene, partial sequence', 'KR607499.1')]
# Q212 44689
# elink query not ok
# Q216 1627871
# nuccore sequences found: 1
# [('Endosymbiont of Amoebozoa sp. JAMX8 gene for 16S ribosomal RNA, partial sequence', 'LC025958.1')]
# Q217 1628022
# nuccore sequences found: 1
# [('Amoebozoa sp. JAMX8 gene for 18S ribosomal RNA, partial sequence', 'LC025975.1')]
# Q218 28197
# elink query not ok
# Q219 5755
# elink query not ok
# Q199 3074276
# nuccore sequences found: 1
# [('Mastigamoeba aspera isolate Lyady small subunit ribosomal RNA gene, partial sequence', 'OR532590.1')]
# Q226 1009887
# nuccore sequences found: 1
# [('Bacterium SCGC AAA071-K20 16S ribosomal RNA gene, partial sequence', 'JF488667.1')]
# Q227 1010454
# nuccore sequences found: 1
# [('Eukaryote SCGC AAA071-K20 18S ribosomal RNA gene, partial sequence', 'JF488770.1')]
# Q228 89044
# elink query not ok
# Q237 375454
# nuccore sequences found: 75
# Q238 90936
# nuccore sequences found: 166
# Q241 2880
# elink query returned exception, skipping
# Q242 1458461
# nuccore sequences found: 82
# Q243 2022334
# nuccore sequences found: 2
# [('Climacodium frauenfeldianum isolate fernando22 small subunit ribosomal RNA gene, partial sequence', 'MK027054.1')]
# Q244 120473
# nuccore sequences found: 1
# [('Symbiont of Climacodium frauenfeldianum 16S ribosomal RNA gene, partial sequence', 'AF193247.1')]
# Q245 1164990
# nuccore sequences found: 1572
# over 200 sequences retrieved, skipping
# Q224 106530
# nuccore sequences found: 4
# Q225 4785
# elink query not ok
# Q247 313588
# nuccore sequences found: 1772
# over 200 sequences retrieved, skipping
# Q248 35128
# no links for 35128, skipping
# Q249 37319
# nuccore sequences found: 3796
# over 200 sequences retrieved, skipping
# Q250 245179
# nuccore sequences found: 25
# Q252 1546519
# nuccore sequences found: 1
# [('Sulfitobacter sp. SA11 16S ribosomal RNA gene, partial sequence', 'KM033243.1')]
# Q255 1546489
# nuccore sequences found: 1
# [('Alcanivorax sp. SA13 16S ribosomal RNA gene, partial sequence', 'KM033245.1')]
# Q236 399391
# nuccore sequences found: 6
# Q257 1546490
# nuccore sequences found: 1
# [('Hyphomonas sp. HV1 16S ribosomal RNA gene, partial sequence', 'KM033232.1')]
# Q258 1546497
# nuccore sequences found: 1
# [('Limnobacter sp. SA4 16S ribosomal RNA gene, partial sequence', 'KM033236.1')]
# Q259 1546500
# nuccore sequences found: 1
# [('Maribacter sp. HV3 16S ribosomal RNA gene, partial sequence', 'KM033234.1')]
# Q260 1546511
# nuccore sequences found: 1
# [('Marinobacter sp. SA8 16S ribosomal RNA gene, partial sequence', 'KM033240.1')]
# Q261 1546513
# nuccore sequences found: 1
# [('Muricauda sp. SA1 16S ribosomal RNA gene, partial sequence', 'KM033235.1')]
# Q262 1546515
# nuccore sequences found: 1
# [('Pseudoalteromonas sp. SA5 16S ribosomal RNA gene, partial sequence', 'KM033237.1')]
# Q263 1546517
# nuccore sequences found: 1
# [('Roseovarius sp. SA33 16S ribosomal RNA gene, partial sequence', 'KM033256.1')]
# Q264 1546518
# nuccore sequences found: 1
# [('Saccharospirillum sp. SA41 16S ribosomal RNA gene, partial sequence', 'KM033262.1')]
# Q265 1546520
# nuccore sequences found: 1
# [('Sulfitobacter sp. SA16 16S ribosomal RNA gene, partial sequence', 'KM033247.1')]
# Q266 1546533
# nuccore sequences found: 1
# [('Thalassospira sp. SA40 16S ribosomal RNA gene, partial sequence', 'KM033261.1')]
# Q272 877583
# nuccore sequences found: 4
# Q273 511435
# nuccore sequences found: 105
# Q274 104083
# nuccore sequences found: 29
# Q276 1580831
# nuccore sequences found: 6505
# over 200 sequences retrieved, skipping
# Q278 450811
# nuccore sequences found: 1
# [('Eucomonympha sp. HsEcA gene for small subunit ribosomal RNA, partial sequence', 'AB326375.1')]
# Q286 1633202
# nuccore sequences found: 490
# over 200 sequences retrieved, skipping
# Q290 2098
# nuccore sequences found: 1914
# over 200 sequences retrieved, skipping
# Q291 5722
# elink query not ok
# Q296 246723
# nuccore sequences found: 1
# [('Mixotricha paradoxa partial 16S-like rRNA gene', 'AJ583377.1')]
# Q299 435141
# nuccore sequences found: 2
# Q300 402894
# nuccore sequences found: 9
# [('Caduceia versatilis small subunit ribosomal RNA gene, partial sequence', 'DQ855405.1')]
# Q304 450820
# nuccore sequences found: 9
# [('Joenia annectens gene for small subunit ribosomal RNA, partial sequence, clone: KfJS4', 'AB458854.1')]
# Q280 377914
# nuccore sequences found: 4469
# over 200 sequences retrieved, skipping
# Q283 36987
# nuccore sequences found: 200
# Q310 641636
# nuccore sequences found: 8
# Q311 641595
# nuccore sequences found: 2
# Q312 641596
# nuccore sequences found: 1
# [('Devescovina arta partial ssu gene for small subunit ribosomal RNA, clone NcDvA25', 'FN377761.1')]
# Q313 641597
# nuccore sequences found: 1
# [('Devescovina sp. ClDv14 partial ssu gene for small subunit ribosomal RNA, clone ClDv14', 'FN377762.1')]
# Q288 36984
# nuccore sequences found: 888
# over 200 sequences retrieved, skipping
# Q314 641598
# nuccore sequences found: 1
# [('Devescovina sp. CsDv11 partial ssu gene for small subunit ribosomal RNA, clone CsDv11', 'FN377763.1')]
# Q315 641599
# nuccore sequences found: 1
# [('Devescovina sp. CbDv02 partial ssu gene for small subunit ribosomal RNA, clone CbDv02', 'FN377764.1')]
# Q316 641600
# nuccore sequences found: 1
# [('Devescovina sp. CdDv09 partial ssu gene for small subunit ribosomal RNA, clone CdDv09', 'FN377765.1')]
# Q317 641601
# nuccore sequences found: 1
# [('Devescovina sp. ChDv22 partial ssu gene for small subunit ribosomal RNA, clone ChDv22', 'FN377766.1')]
# Q298 13139
# nuccore sequences found: 105
# Q325 223394
# nuccore sequences found: 28
# Q326 641610
# nuccore sequences found: 3
# Q327 105785
# elink query not ok
# Q328 105780
# nuccore sequences found: 53
# Q329 105782
# nuccore sequences found: 32
# Q330 641612
# nuccore sequences found: 11
# Q302 641613
# nuccore sequences found: 13
# [('Cryptotermes cavifrons isolate MX313 small subunit ribosomal RNA gene, partial sequence', 'OL895181.1')]
# Q331 63628
# nuccore sequences found: 42
# Q332 1408204
# nuccore sequences found: 967
# over 200 sequences retrieved, skipping
# Q305 256709
# nuccore sequences found: 172
# Q335 1408203
# nuccore sequences found: 1
# [('Candidatus Endomicrobium pyrsonymphae clone Pv-1 16S ribosomal RNA gene, partial sequence', 'AY512589.1')]
# Q336 390252
# nuccore sequences found: 1
# [('Pseudotrichonympha sp. MA79Cp-P1 gene for small subunit ribosomal RNA, partial sequence', 'AB262487.1')]
# Q339 390253
# nuccore sequences found: 1
# [('Pseudotrichonympha sp. LA10Cp-P1 gene for small subunit ribosomal RNA, partial sequence', 'AB262488.1')]
# Q341 390254
# nuccore sequences found: 1
# [('Pseudotrichonympha sp. BR75CpT-P1 gene for small subunit ribosomal RNA, partial sequence', 'AB262489.1')]
# Q343 390255
# nuccore sequences found: 1
# Q345 390256
# nuccore sequences found: 1
# [('Pseudotrichonympha sp. BR78HtT-P2 gene for small subunit ribosomal RNA, partial sequence', 'AB262491.1')]
# Q346 390257
# nuccore sequences found: 1
# [('Pseudotrichonympha sp. MA26TgP-P1 gene for small subunit ribosomal RNA, partial sequence', 'AB262492.1')]
# Q333 127387
# nuccore sequences found: 66
# Q334 2005061
# no links for 2005061, skipping
# Q349 390258
# nuccore sequences found: 1
# [('Pseudotrichonympha sp. SA16PsA-P1 gene for small subunit ribosomal RNA, partial sequence', 'AB262493.1')]
# Q351 390259
# nuccore sequences found: 1
# Q353 390260
# nuccore sequences found: 1
# [('Pseudotrichonympha sp. BR76RhH-P2 gene for small subunit ribosomal RNA, partial sequence', 'AB262495.1')]
# Q355 390261
# nuccore sequences found: 1
# [('Pseudotrichonympha sp. LA19Sc-P8 gene for small subunit ribosomal RNA, partial sequence', 'AB262496.1')]
# Q357 390262
# nuccore sequences found: 1
# [('Pseudotrichonympha sp. AU05Sc-P1 gene for small subunit ribosomal RNA, partial sequence', 'AB262497.1')]
# Q359 390263
# nuccore sequences found: 1
# [('Pseudotrichonympha sp. MY26Pa-P2 gene for small subunit ribosomal RNA, partial sequence', 'AB262498.1')]
# Q360 1725232
# nuccore sequences found: 2
# Q364 1294086
# nuccore sequences found: 1
# [('Staurojoenina mulleri small subunit ribosomal RNA gene, partial sequence', 'JX847580.1')]
# Q365 274559
# nuccore sequences found: 1
# [('Candidatus Vestibaculum illigatum 16S ribosomal RNA gene, partial sequence', 'AY540335.1')]
# Q367 1580832
# nuccore sequences found: 6
# Q368 285686
# nuccore sequences found: 11
# Q369 467085
# nuccore sequences found: 3898
# over 200 sequences retrieved, skipping
# Q370 2847785
# nuccore sequences found: 17
# Q371 2847784
# nuccore sequences found: 9
# Q372 66290
# nuccore sequences found: 19
# Q373 2847786
# nuccore sequences found: 7
# Q374 450818
# nuccore sequences found: 1
# [('Oxymonas sp. NcOxA gene for small subunit ribosomal RNA, partial sequence', 'AB326383.1')]
# Q382 222440
# elink query not ok
# Q383 31290
# nuccore sequences found: 48
# Q385 36333
# nuccore sequences found: 53
# Q386 40324
# elink query not ok
# Q388 759128
# nuccore sequences found: 3
# Q366 2049371
# nuccore sequences found: 2
# Q391 56466
# nuccore sequences found: 4887
# over 200 sequences retrieved, skipping
# Q392 1130797
# nuccore sequences found: 2
# Q398 191721
# nuccore sequences found: 2
# [('Phacus ocellatus voucher SAG:228.80 18S small subunit ribosomal RNA gene, partial sequence', 'AF445458.1')]
# Q399 86638
# nuccore sequences found: 12
# Q402 298306
# nuccore sequences found: 43
# Q403 459229
# nuccore sequences found: 1
# Q408 563839
# nuccore sequences found: 1
# [('Calkinsia aureus 18S ribosomal RNA gene, partial sequence', 'EU753419.1')]
# Q412 1075202
# nuccore sequences found: 1
# [('Verrucomicrobia bacterium symbiont of Bihospites bacati 16S ribosomal RNA gene, partial sequence', 'JN379459.1')]
# Q400 186756
# nuccore sequences found: 9
# Q420 233181
# nuccore sequences found: 12
# [('Kinetoplastibacterium blastocrithidii 16S ribosomal RNA gene, partial sequence', 'L29265.1')]
# Q421 28005
# elink query not ok
# Q422 994696
# nuccore sequences found: 12
# Q423 5657
# nuccore sequences found: 146
# Q424 994695
# nuccore sequences found: 12
# Q425 1003336
# nuccore sequences found: 146
# Q405 215769
# nuccore sequences found: 7
# Q426 33056
# nuccore sequences found: 62
# Q427 59799
# nuccore sequences found: 2400
# over 200 sequences retrieved, skipping
# Q416 75058
# nuccore sequences found: 2336
# over 200 sequences retrieved, skipping
# Q428 994692
# nuccore sequences found: 16
# Q429 59800
# nuccore sequences found: 158
# Q430 999947
# nuccore sequences found: 23
# Q409 797089
# nuccore sequences found: 3
# Q413 127150
# nuccore sequences found: 164
# Q415 312471
# elink query not ok
# Q417 351716
# nuccore sequences found: 5
# Q418 1729212
# nuccore sequences found: 1
# [('Neobodo borokensis strain B-74 18S ribosomal RNA gene, partial sequence', 'KT223311.1')]
# Q438 100131
# nuccore sequences found: 2
# Q439 100380
# nuccore sequences found: 1
# Q440 469766
# nuccore sequences found: 2
# Q446 1674981
# nuccore sequences found: 1
# [('Methanogenic endosymbiont of Metopus contortus gene for 16S ribosomal RNA, partial sequence, clone: NNCTYH004', 'LC062151.1')]
# Q447 1674989
# nuccore sequences found: 1
# [('Endosymbiont of Metopus sp. gene for 16S ribosomal RNA, partial sequence, clone: NNCTYH060', 'LC062207.1')]
# Q448 2661169
# nuccore sequences found: 9
# Q435 402029
# nuccore sequences found: 109
# Q436 37688
# nuccore sequences found: 68
# Q443 2315562
# nuccore sequences found: 1
# [('Metopus vestitus 18S ribosomal RNA gene, partial sequence', 'MF360251.1')]
# Q445 392813
# nuccore sequences found: 30
# Q468 39564
# nuccore sequences found: 5
# [('Pseudomicrothorax dubius partial 18S rRNA gene', 'FM201298.1')]
# Q469 549339
# nuccore sequences found: 3
# Q454 1926408
# nuccore sequences found: 4
# Q471 243899
# nuccore sequences found: 5
# [("Endosymbiont 'TC1' of Trimyema compressum gene for 16S ribosomal RNA", 'AB118592.1')]
# Q472 243898
# nuccore sequences found: 1
# [("Endosymbiont 'TS1' of Trimyema compressum gene for 16S ribosomal RNA", 'AB118591.1')]
# Q473 35113
# nuccore sequences found: 2
# Q458 60006
# nuccore sequences found: 1
# [('Strombidium purpureum 18S ribosomal RNA gene, complete sequence', 'U97112.1')]
# Q480 74790
# elink query returned exception, skipping
# Q481 1732522
# nuccore sequences found: 4
# Q482 554065
# elink query not ok
# Q464 132687
# nuccore sequences found: 9
# Q465 2004969
# nuccore sequences found: 3
# Q483 532145
# nuccore sequences found: 48
# Q484 65126
# nuccore sequences found: 335
# over 200 sequences retrieved, skipping
# Q485 1920990
# nuccore sequences found: 3
# [('Candidatus Fokinia cryptica isolate US_Bl 11III1 F 16S ribosomal RNA gene, partial sequence', 'KU736846.1')]
# Q486 1921001
# nuccore sequences found: 28
# Q487 272624
# nuccore sequences found: 335
# over 200 sequences retrieved, skipping
# Q488 5885
# nuccore sequences found: 296
# over 200 sequences retrieved, skipping
# Q470 1249563
# nuccore sequences found: 1
# [('Sonderia vorax partial 18S rRNA gene, isolate stagno 1', 'HF547270.1')]
# Q494 1436882
# nuccore sequences found: 1
# [('Halobacteriaceae bacterium TS-2013 16S ribosomal RNA gene, partial sequence', 'KF736828.1')]
# Q495 1367513
# nuccore sequences found: 1
# [('Platynematum sp. 1 TS-2013 small subunit ribosomal RNA gene, partial sequence; macronuclear', 'KF301567.1')]
# Q497 5932
# elink query not ok
# Q501 404942
# nuccore sequences found: 5
# Q502 374667
# nuccore sequences found: 13
# Q504 1905839
# nuccore sequences found: 1
# [('Candidatus Navis piranensis strain Slovenia 16S small subunit ribosomal RNA gene, partial sequence', 'KX669263.1')]
# Q505 1906146
# nuccore sequences found: 1
# [('Zoothamnium ignavum 18S ribosomal RNA gene, partial sequence', 'KX669262.1')]
# Q508 909204
# nuccore sequences found: 6
# Q511 236099
# nuccore sequences found: 1
# [('Marinobacter sp. DG879 small subunit ribosomal RNA gene, partial sequence', 'AY258107.1')]
# Q512 39447
# elink query not ok
# Q514 107036
# nuccore sequences found: 97
# Q509 7959
# elink query not ok
# Q510 425813
# nuccore sequences found: 2
# [('Woloszynskia pascheri strain CCAC0075 small subunit ribosomal RNA gene, partial sequence', 'EF058253.1')]
# Q526 292414
# nuccore sequences found: 371
# over 200 sequences retrieved, skipping
# Q527 71001
# nuccore sequences found: 639
# over 200 sequences retrieved, skipping
# Q529 39448
# nuccore sequences found: 383
# over 200 sequences retrieved, skipping
# Q516 1573495
# nuccore sequences found: 63
# Q520 2926
# elink query not ok
# Q521 2932
# elink query not ok
# Q522 142111
# nuccore sequences found: 126
# Q525 59809
# nuccore sequences found: 2
# [('Peridinium balticum small subunit ribosomal RNA gene, partial sequence', 'AF231803.1')]
# Q596 70075
# elink query returned exception, skipping
# Q597 132935
# nuccore sequences found: 46
# Q598 2006183
# nuccore sequences found: 113
# Q611 2936506
# nuccore sequences found: 1
# [('Chlamydiia bacterium (ex Euplotes octocarinatus) isolate Zam5b-1 16S ribosomal RNA gene, partial sequence', 'ON271409.1')]
# Q612 2555681
# nuccore sequences found: 8
# Q613 2558174
# nuccore sequences found: 9
# Q614 2558173
# nuccore sequences found: 7
# Q615 1151776
# nuccore sequences found: 1
# [('Spirostomum sp. 72 partial 18S rRNA gene, strain 72', 'HE664173.1')]
# Q616 367937
# nuccore sequences found: 13
# Q617 1808959
# nuccore sequences found: 15
# [('Candidatus Pandoraea novymonadis strain E262-ES 16S ribosomal RNA gene, partial sequence; 16S-23S ribosomal RNA intergenic spacer, complete sequence; and 23S ribosomal RNA gene, partial sequence', 'KT944310.1')]
# Q618 1808958
# nuccore sequences found: 11
# Q619 2066024
# nuccore sequences found: 5
# [('Candidatus Cytomitobacter primus 16S ribosomal RNA gene, partial sequence', 'MG719947.1')]
# Q620 2066025
# nuccore sequences found: 1
# [('Proteobacteria bacterium 1605 16S ribosomal RNA gene, partial sequence', 'MG719948.1')]
# Q624 2741701
# nuccore sequences found: 1
# Q626 2794224
# nuccore sequences found: 3
# [('Euplotes vanleeuwenhoeki partial 18S rRNA gene, isolate SR2A_113', 'OU070011.1')]
# Q627 2529394
# nuccore sequences found: 2
# [('Candidatus Pinguicoccus supinus 16S ribosomal RNA gene, partial sequence', 'MK569697.1')]
# Q629 1756192
# nuccore sequences found: 11
# Q631 1909704
# nuccore sequences found: 2
# Q621 2508216
# nuccore sequences found: 48
# [('Diplonema japonicum small subunit ribosomal RNA gene, partial sequence; and exon; mitochondrial', 'MN109082.1')]
# Q623 2022782
# nuccore sequences found: 3
# Q632 2690157
# nuccore sequences found: 4
# Q633 2691107
# nuccore sequences found: 1
# [('Rhogostoma pseudocylindrica strain RC small subunit ribosomal RNA gene, partial sequence', 'MN860276.1')]
# Q635 2691104
# no links for 2691104, skipping
# Q637 2690155
# nuccore sequences found: 1
# [('Gammaproteobacteria bacterium ex CCAP 1943/6 clone 1 16S ribosomal RNA gene, partial sequence', 'MN848752.1')]
# Q638 2066483
# nuccore sequences found: 2
# Q639 673862
# nuccore sequences found: 3
# Q641 2806609
# nuccore sequences found: 3
# Q642 109354
# nuccore sequences found: 51
# Q654 5757
# nuccore sequences found: 142
# Q643 2490542
# nuccore sequences found: 22
# Q644 122938
# nuccore sequences found: 30
# Q645 1222018
# nuccore sequences found: 3
# Q646 1222017
# nuccore sequences found: 4
# Q647 2152888
# nuccore sequences found: 190
# Q648 2152889
# nuccore sequences found: 93
# Q649 2152891
# nuccore sequences found: 36
# Q650 2115978
# nuccore sequences found: 112
# Q651 1032745
# nuccore sequences found: 16
# Q652 41882
# elink query returned exception, skipping
# Q653 1620466
# nuccore sequences found: 1
# [('Rickettsiales bacterium endosymbiont of Mesostigma viride strain NIES-995 16S ribosomal RNA gene, partial sequence', 'KJ808701.1')]
# Q655 2487131
# nuccore sequences found: 25
# Q653 2866314
# nuccore sequences found: 3
# Q662 2213239
# nuccore sequences found: 7
# Q669 2213234
# nuccore sequences found: 2
# Q671 2213237
# nuccore sequences found: 5
# Q672 2213235
# nuccore sequences found: 12
# Q673 2213236
# nuccore sequences found: 1
# [('Tropidoatractus spinosus isolate BLUFF8 18S ribosomal RNA gene, partial sequence', 'MG896717.1')]
# Q675 1930931
# nuccore sequences found: 1
# [('Meyerella sp. OL-2016 18S ribosomal RNA gene, partial sequence', 'KX669637.1')]
# Q676 1930930
# nuccore sequences found: 2
# Q677 1201934
# nuccore sequences found: 11
# Q968 77082
# nuccore sequences found: 11
# Q974 2609337
# nuccore sequences found: 5
# Q975 1511244
# nuccore sequences found: 9
# [('Picromerus bidens voucher MRCPEN262 small subunit ribosomal RNA gene, partial sequence', 'MT265646.1')]
# Q978 233257
# nuccore sequences found: 22
# Q979 2570586
# nuccore sequences found: 323
# over 200 sequences retrieved, skipping
# Q980 86105
# nuccore sequences found: 502
# over 200 sequences retrieved, skipping
# Q983 2601646
# nuccore sequences found: 4
# Q1246 2652329
# no links for 2652329, skipping
# Q1247 1576550
# nuccore sequences found: 4
# Q1248 1295810
# nuccore sequences found: 4
# [('Trypanosomatidae sp. ECU-07 small subunit ribosomal RNA gene, partial sequence', 'KC206002.1')]
# Q1249 7163
# nuccore sequences found: 100
# Q1261 2540710
# nuccore sequences found: 249
# over 200 sequences retrieved, skipping
# Q1489 521161
# nuccore sequences found: 42
# Q1490 1705730
# nuccore sequences found: 158
# Q1491 521162
# nuccore sequences found: 38
# Q1496 2696086
# nuccore sequences found: 44
# Q1498 1265509
# nuccore sequences found: 6
# Q1505 1703786
# nuccore sequences found: 23
# Q1506 2185085
# nuccore sequences found: 8
# Q1507 2972634
# nuccore sequences found: 1
# Q1508 2055910
# nuccore sequences found: 291
# over 200 sequences retrieved, skipping
# Q1510 43138
# nuccore sequences found: 460
# over 200 sequences retrieved, skipping
# Q1512 1629334
# nuccore sequences found: 177
# Q1515 5888
# elink query not ok
# Q1530 547466
# nuccore sequences found: 1
# [('Candidatus Paraholospora nucleivisitans 16S ribosomal RNA gene, partial sequence', 'EU652696.1')]
# Q1531 65128
# nuccore sequences found: 108
# Q1532 35117
# nuccore sequences found: 6
# Q1533 2601668
# nuccore sequences found: 4
# Q1534 1696035
# nuccore sequences found: 2
# Q1535 1696036
# nuccore sequences found: 1758
# over 200 sequences retrieved, skipping
# Q1536 1435003
# nuccore sequences found: 6
# Q1537 1435005
# elink query not ok
# Q1538 2486577
# nuccore sequences found: 252
# over 200 sequences retrieved, skipping
# Q1539 2486578
# nuccore sequences found: 2
# Q1541 86106
# nuccore sequences found: 3
# [('Endosymbiont of Acanthamoeba sp. UWC8 16S ribosomal RNA gene, partial sequence', 'AF069963.1')]
# Q1544 1169117
# nuccore sequences found: 4
# Q1545 431043
# nuccore sequences found: 2
# Q1546 2989698
# nuccore sequences found: 1
# Q1547 1276921
# nuccore sequences found: 2
# Q1548 1082868
# nuccore sequences found: 308
# over 200 sequences retrieved, skipping
# Q1549 1904031
# nuccore sequences found: 9
# Q1550 1204725
# nuccore sequences found: 58
# Q530 398580
# nuccore sequences found: 73
# Q531 39449
# elink query not ok
# Q532 476202
# nuccore sequences found: 1458
# over 200 sequences retrieved, skipping
# Q533 2777155
# nuccore sequences found: 60
# Q540 2652803
# nuccore sequences found: 11
# Q542 1802984
# nuccore sequences found: 597
# over 200 sequences retrieved, skipping
# Q543 653937
# nuccore sequences found: 1
# [('Francisella sp. GP-2009 16S rRNA gene (partial), tRNA-Ile gene, tRNA-Ala gene and 23S rRNA gene (partial)', 'FN398155.1')]
# Q544 5938
# nuccore sequences found: 44
# Q545 1167250
# nuccore sequences found: 5
# Q546 5940
# nuccore sequences found: 90
# Q547 1969603
# nuccore sequences found: 1
# [('Pseudovorticella sp. guadeloupensis small subunit ribosomal RNA gene, partial sequence', 'KY777484.1')]
# Q548 1969606
# nuccore sequences found: 1
# [('Bacterium ectosymbiont of Pseudovorticella sp. guadeloupensis isolate 1 16S ribosomal RNA gene, partial sequence', 'KY777480.1')]
# Q535 7719
# elink query not ok
# Q552 2163193
# nuccore sequences found: 2
# Q553 2770581
# nuccore sequences found: 125
# [('Candidatus Sarmatiella mevalonica isolate WO2 16S ribosomal RNA gene, partial sequence', 'MT984300.1')]
# Q554 65130
# nuccore sequences found: 68
# Q555 5886
# nuccore sequences found: 764
# over 200 sequences retrieved, skipping
# Q556 2163644
# nuccore sequences found: 3
# [('Candidatus Deianiraea vastatrix clone CyL4-1 16S ribosomal RNA gene, partial sequence', 'MH197138.1')]
# Q558 576610
# nuccore sequences found: 1575
# over 200 sequences retrieved, skipping
# Q559 471435
# nuccore sequences found: 7
# Q560 1048934
# nuccore sequences found: 1
# [('Euplotes sp. PUHP partial 18S rRNA gene, isolate PUHP population', 'FR873721.1')]
# Q561 1048933
# nuccore sequences found: 1
# [('Euplotes sp. EMP partial 18S rRNA gene, isolate EMP population', 'FR873720.1')]
# Q562 151035
# nuccore sequences found: 16
# Q563 5941
# nuccore sequences found: 18
# Q564 1048740
# nuccore sequences found: 10
# Q565 5942
# nuccore sequences found: 61
# Q567 223181
# nuccore sequences found: 8
# Q568 151034
# nuccore sequences found: 12
# Q557 2022780
# nuccore sequences found: 1
# [('Discomorphella pedroenasi isolate bar small subunit ribosomal RNA gene, partial sequence', 'MF563969.1')]
# Q569 1664265
# nuccore sequences found: 7
# [('Bacterium Sq1_host partial 16S rRNA gene, strain Sq1 host', 'LN864514.1')]
# Q571 675776
# nuccore sequences found: 146
# Q572 2716877
# nuccore sequences found: 121
# Q573 1346319
# nuccore sequences found: 92
# Q574 44030
# nuccore sequences found: 279
# over 200 sequences retrieved, skipping
# Q575 109353
# nuccore sequences found: 55
# Q576 1346323
# nuccore sequences found: 1
# [('Candidatus Gigarickettsia flagellata partial 16S rRNA gene, isolated from Spirostomum minus strain SS03', 'HG315613.1')]
# Q577 2067671
# no links for 2067671, skipping
# Q578 2067670
# nuccore sequences found: 2
# [('Candidatus Trichorickettsia mobilis subsp. hyperinfectiva strain CyL 8-33 16S ribosomal RNA gene, partial sequence', 'MF039744.1')]
# Q579 2067672
# no links for 2067672, skipping
# Q580 83916
# nuccore sequences found: 36
# Q581 1937525
# nuccore sequences found: 1
# [('Symbiont of Cochliopodium minus partial 16S rRNA gene, isolate PDD8', 'LT716083.1')]
# Q582 313997
# nuccore sequences found: 46
# Q583 1917973
# nuccore sequences found: 50
# Q584 1917417
# nuccore sequences found: 659
# over 200 sequences retrieved, skipping
# Q585 362614
# nuccore sequences found: 538
# over 200 sequences retrieved, skipping
# Q586 2496102
# nuccore sequences found: 17
# Q587 566470
# nuccore sequences found: 12
# Q589 2184471
# nuccore sequences found: 1
# [('Bacterium endosymbiont of Frontonia salmastra isolate ITM-5F-2 16S ribosomal RNA gene, partial sequence', 'MH319377.1')]
# Q590 2184470
# nuccore sequences found: 1
# [('Frontonia salmastra isolate ITM-5F-2 small subunit ribosomal RNA gene, partial sequence', 'MH319376.1')]
# Q591 1917435
# nuccore sequences found: 1
# Q592 1169118
# nuccore sequences found: 5
# Q593 44029
# nuccore sequences found: 268
# over 200 sequences retrieved, skipping
# Q594 49893
# nuccore sequences found: 9
# Q595 2006182
# nuccore sequences found: 71

# %%
len(qid2repseq)
# Out:
# 137

# %%
# with open("qid2repseq.json", "w") as fh:
#     json.dump(qid2repseq, fh)

# %%
# with open("qid2repseq.json", "r") as fh:
#     qid2repseq = json.load(fh)

# %%
wbi = WikibaseIntegrator(login=login)

# %%
for qid in qid2repseq:
    acc = qid2repseq[qid][1].split(".")[0]
    print(qid, acc)
    item = wbi.item.get(qid)
    item.claims.add(datatypes.String(prop_nr="P34", value=acc))
    item.write(summary="Link to representative SSU rRNA sequence by NCBI taxon ID")
# Out:
# Q16 AY187925
# Q62 MW203126
# Q63 MK543441
# Q92 MK547175
# Q118 AF107209
# Q120 AF107210
# Q122 U37762
# Q130 AB073554
# Q132 AB900796
# Q136 U57696
# Q138 LC086369
# Q146 AY598719
# Q151 KF697197
# Q152 KF697195
# Q163 LC025959
# Q164 LC025974
# Q166 KF705035
# Q167 FJ766469
# Q169 JF694281
# Q170 AF177427
# Q171 AF352390
# Q172 AF352388
# Q173 AF352387
# Q174 AF352389
# Q175 AF352391
# Q176 AF132134
# Q43 LT621912
# Q61 AB713411
# Q81 KT023596
# Q107 AY364636
# Q177 AF132137
# Q179 AF132136
# Q183 AF366580
# Q185 AF366583
# Q193 AM412761
# Q197 AY741401
# Q198 EF492067
# Q203 KX156800
# Q204 KX156801
# Q205 KX156802
# Q211 KR607499
# Q216 LC025958
# Q217 LC025975
# Q199 OR532590
# Q226 JF488667
# Q227 JF488770
# Q243 MK027054
# Q244 AF193247
# Q252 KM033243
# Q255 KM033245
# Q257 KM033232
# Q258 KM033236
# Q259 KM033234
# Q260 KM033240
# Q261 KM033235
# Q262 KM033237
# Q263 KM033256
# Q264 KM033262
# Q265 KM033247
# Q266 KM033261
# Q278 AB326375
# Q296 AJ583377
# Q300 DQ855405
# Q304 AB458854
# Q312 FN377761
# Q313 FN377762
# Q314 FN377763
# Q315 FN377764
# Q316 FN377765
# Q317 FN377766
# Q302 OL895181
# Q335 AY512589
# Q336 AB262487
# Q339 AB262488
# Q341 AB262489
# Q345 AB262491
# Q346 AB262492
# Q349 AB262493
# Q353 AB262495
# Q355 AB262496
# Q357 AB262497
# Q359 AB262498
# Q364 JX847580
# Q365 AY540335
# Q374 AB326383
# Q398 AF445458
# Q408 EU753419
# Q412 JN379459
# Q420 L29265
# Q418 KT223311
# Q446 LC062151
# Q447 LC062207
# Q443 MF360251
# Q468 FM201298
# Q471 AB118592
# Q472 AB118591
# Q458 U97112
# Q485 KU736846
# Q470 HF547270
# Q494 KF736828
# Q495 KF301567
# Q504 KX669263
# Q505 KX669262
# Q511 AY258107
# Q510 EF058253
# Q525 AF231803
# Q611 ON271409
# Q615 HE664173
# Q617 KT944310
# Q619 MG719947
# Q620 MG719948
# Q626 OU070011
# Q627 MK569697
# Q621 MN109082
# Q633 MN860276
# Q637 MN848752
# Q653 KJ808701
# Q673 MG896717
# Q675 KX669637
# Q975 MT265646
# Q1248 KC206002
# Q1530 EU652696
# Q1541 AF069963
# Q543 FN398155
# Q547 KY777484
# Q548 KY777480
# Q553 MT984300
# Q556 MH197138
# Q560 FR873721
# Q561 FR873720
# Q557 MF563969
# Q569 LN864514
# Q576 HG315613
# Q578 MF039744
# Q581 LT716083
# Q589 MH319377
# Q590 MH319376
